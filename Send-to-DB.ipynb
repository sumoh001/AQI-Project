# %% [markdown]
# # Jupyter with PostgreSQL

# %% [markdown]
# ## Libararies and Settings

# %%
# Variables
import config

# Preprocessing
import preprocessing_functions as pf

# Libraries
import pandas as pd
from sqlalchemy import text

# Settings
import warnings
warnings.filterwarnings("ignore")

print(config.date_heute)
print(config.date_Vor30Tagen)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Variables
# ----> 2 import config
#       4 # Preprocessing
#       5 import preprocessing_functions as pf
#
# File c:\Users\stump\OneDrive - ZHAW\ADS\AQI\AQI-Project-1\config.py:31
#      28 thirty_days_ago = datetime.today() - timedelta(days=30)
#      30 ## Formatierung im gewünschten Format
# ---> 31 date_heute = date.today().strftime("%Y-%m-%d")
#      32 date_Vor30Tagen = thirty_days_ago.strftime('%Y-%m-%d')
#
# NameError: name 'date' is not defined

# %% [markdown]
# ## Create database connection

# %%
#Connection using preprocessing function
pf.db_connect(config.db_name)

#Connection using explicit programming
#conn = psycopg2.connect("host=localhost dbname=postgres user=admin password=secret")

# %% [markdown]
# ## Read data

# %%
# CSV-Datei mit den Daten
#csv_file = 'ausgabe.csv'

df = pd.read_csv(config.csv_file, sep=',')
df.head(5)
# Out:
#    weathercode_best_match  temperature_2m_max_best_match  \
# 0                      80                           10.8
# 1                       3                           13.1
# 2                      45                           16.6
# 3                      80                           14.1
# 4                      61                           14.3
#
#    temperature_2m_min_best_match  apparent_temperature_max_best_match  \
# 0                            5.7                                  8.1
# 1                            5.1                                 10.3
# 2                            3.9                                 15.0
# 3                            9.5                                 11.8
# 4                            8.6                                 11.7
#
#    apparent_temperature_min_best_match           sunrise            sunset  \
# 0                                  4.1  2023-04-08T06:49  2023-04-08T20:05
# ...

# %% [markdown]
# ## Write data to database

# %%
#Connection using preprocessing function
df.to_sql(config.db_table, config.db_login, if_exists='append', index=False)

#Connection using explicit programming
##engine = create_engine('postgresql://admin:secret@localhost:5432/postgres')
# Out:
# 30

# %% [markdown]
# ## Make SQL query

# %%
SQLquery = text('SELECT * FROM ' + config.db_table)
df_sub = pd.read_sql(SQLquery, con=config.db_login.connect())

df_sub.head()
# Out:
#   weathercode_best_match temperature_2m_max_best_match  \
# 0                     80                          10.8
# 1                      3                          13.1
# 2                     45                          16.6
# 3                     80                          14.1
# 4                     61                          14.3
#
#   temperature_2m_min_best_match apparent_temperature_max_best_match  \
# 0                           5.7                                 8.1
# 1                           5.1                                10.3
# 2                           3.9                                15.0
# 3                           9.5                                11.8
# 4                           8.6                                11.7
#
#   apparent_temperature_min_best_match           sunrise            sunset  \
# 0                                 4.1  2023-04-08T06:49  2023-04-08T20:05
# ...

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-05-09 19:25:35
# Python Version: 3.10.9
# -----------------------------------
