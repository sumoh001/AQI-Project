# %% [markdown]
# 1. Laden von Daten und Bibliotheken

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Daten laden
data = pd.read_csv('merged_tables.csv')

# %% [markdown]
# 2. Überblick über die Daten

# %%
# Ersten fünf Zeilen der Daten anzeigen
print(data.head())

# Datenform und Datentypen anzeigen
print(data.info())

# Statistische Zusammenfassung anzeigen
print(data.describe())
# Out:
#                       name  datetime  tempmax  tempmin  temp  feelslikemax
# 0  Zch_Stampfenbachstrasse  04.01.01      6.6      0.1   3.3           4.0  \
# 1  Zch_Stampfenbachstrasse  05.01.01      7.3      1.1   4.3           6.4
# 2  Zch_Stampfenbachstrasse  06.01.01      8.2      3.4   6.2           7.9
# 3  Zch_Stampfenbachstrasse  07.01.01      2.4      1.1   1.7           2.1
# 4  Zch_Stampfenbachstrasse  08.01.01      2.2      1.2   1.8           2.2
#
#    feelslikemin  feelslike  dew  humidity  ...
# 0           0.1        2.1  0.5      82.0  ...  \
# 1           1.1        3.9  1.9      84.8  ...
# 2           2.0        4.9  4.9      91.9  ...
# 3          -0.2        1.5  0.8      93.5  ...
# 4           1.2        1.8  0.8      92.9  ...
#
#                                          description  icon
# 0  Partly cloudy throughout the day with late aft...  rain  \
# 1        Partly cloudy throughout the day with rain.  rain
# 2  Cloudy skies throughout the day with a chance ...  rain
# 3  Cloudy skies throughout the day with a chance ...  rain
# 4  Cloudy skies throughout the day with a chance ...  rain
#
#                               stations     Datum                 Standort
# 0  06689099999,06670099999,06660099999  04.01.01  Zch_Stampfenbachstrasse  \
# 1  06689099999,06670099999,06660099999  05.01.01  Zch_Stampfenbachstrasse
# 2  06689099999,06670099999,06660099999  06.01.01  Zch_Stampfenbachstrasse
# 3  06689099999,06670099999,06660099999  07.01.01  Zch_Stampfenbachstrasse
# 4  06689099999,06670099999,06660099999  08.01.01  Zch_Stampfenbachstrasse
#
#    Parameter  Intervall  Einheit   Wert     Status
# 0       PM10         d1    µg/m3  22.84  bereinigt
# 1       PM10         d1    µg/m3  22.63  bereinigt
# 2       PM10         d1    µg/m3  10.93  bereinigt
# 3       PM10         d1    µg/m3    NaN  bereinigt
# 4       PM10         d1    µg/m3  18.01  bereinigt
#
# [5 rows x 40 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24450 entries, 0 to 24449
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              24450 non-null  object
#  1   datetime          24450 non-null  object
#  2   tempmax           24450 non-null  float64
#  3   tempmin           24450 non-null  float64
#  4   temp              24450 non-null  float64
#  5   feelslikemax      24450 non-null  float64
#  6   feelslikemin      24450 non-null  float64
#  7   feelslike         24450 non-null  float64
#  8   dew               24450 non-null  float64
#  9   humidity          24450 non-null  float64
#  10  precip            24450 non-null  float64
#  11  precipprob        24450 non-null  int64
#  12  precipcover       24450 non-null  float64
#  13  preciptype        13908 non-null  object
#  14  snow              24450 non-null  float64
#  15  snowdepth         24450 non-null  float64
#  16  windgust          18864 non-null  float64
#  17  windspeed         24450 non-null  float64
#  18  winddir           24450 non-null  float64
#  19  sealevelpressure  22260 non-null  float64
#  20  cloudcover        24450 non-null  float64
#  21  visibility        24360 non-null  float64
#  22  solarradiation    14607 non-null  float64
#  23  solarenergy       14607 non-null  float64
#  24  uvindex           14607 non-null  float64
#  25  severerisk        1431 non-null   float64
#  26  sunrise           24450 non-null  object
#  27  sunset            24450 non-null  object
#  28  moonphase         24450 non-null  float64
#  29  conditions        24450 non-null  object
#  30  description       24450 non-null  object
#  31  icon              24450 non-null  object
#  32  stations          24450 non-null  object
#  33  Datum             24450 non-null  object
#  34  Standort          24450 non-null  object
#  35  Parameter         24450 non-null  object
#  36  Intervall         24450 non-null  object
#  37  Einheit           24450 non-null  object
#  38  Wert              23607 non-null  float64
#  39  Status            24450 non-null  object
# dtypes: float64(24), int64(1), object(15)
# memory usage: 7.5+ MB
# None
#             tempmax       tempmin          temp  feelslikemax  feelslikemin
# count  24450.000000  24450.000000  24450.000000  24450.000000  24450.000000  \
# mean      14.085055      6.580454     10.049067     13.641276      5.426552
# std        8.837775      6.678150      7.503874      9.295292      7.739552
# min      -10.600000    -16.800000    -13.300000    -15.400000    -23.100000
# 25%        7.000000      1.200000      4.100000      5.800000     -0.700000
# 50%       14.300000      6.700000     10.200000     14.300000      5.600000
# 75%       21.000000     12.100000     16.000000     21.000000     12.100000
# max       36.200000     24.000000     27.500000     35.900000     24.000000
#
#           feelslike           dew      humidity        precip    precipprob
# count  24450.000000  24450.000000  24450.000000  24450.000000  24450.000000  \
# mean       9.322896      5.498785     76.011558      2.811476     56.576687
# std        8.242054      6.502936     12.028492      6.144332     49.566598
# min      -20.000000    -19.200000     36.000000      0.000000      0.000000
# 25%        2.500000      0.500000     67.800000      0.000000      0.000000
# 50%        9.800000      5.600000     77.600000      0.019500    100.000000
# 75%       16.000000     11.000000     85.500000      2.683000    100.000000
# max       28.600000     19.200000     99.300000     73.355000    100.000000
#
#        ...       winddir  sealevelpressure    cloudcover    visibility
# count  ...  24450.000000      22260.000000  24450.000000  24360.000000  \
# mean   ...    170.240699       1017.724771     64.413718     11.800813
# std    ...    105.728387          7.756560     25.452552      6.946393
# min    ...      0.000000        982.100000      0.000000      0.100000
# 25%    ...     47.500000       1013.200000     47.500000      8.300000
# 50%    ...    219.400000       1017.700000     70.800000     10.000000
# 75%    ...    250.200000       1022.500000     86.100000     12.800000
# max    ...    360.000000       1044.500000    100.000000     61.600000
#
#        solarradiation   solarenergy       uvindex   severerisk     moonphase
# count    14607.000000  14607.000000  14607.000000  1431.000000  24450.000000  \
# mean       145.397412     12.546313      5.294927    11.614256      0.482319
# std         93.068489      8.043677      2.589642     6.740498      0.288589
# min          2.200000      0.000000      0.000000    10.000000      0.000000
# 25%         68.200000      5.900000      3.000000    10.000000      0.250000
# 50%        128.600000     11.100000      5.000000    10.000000      0.480000
# 75%        216.700000     18.700000      8.000000    10.000000      0.750000
# max        377.200000     32.700000     10.000000    60.000000      0.980000
#
#                Wert
# count  23607.000000
# mean      21.127181
# std       13.262062
# min        0.930000
# 25%       12.060000
# 50%       17.950000
# 75%       26.550000
# max      163.450000
#
# [8 rows x 25 columns]

# %% [markdown]
# 3. Visualisierung von Daten

# %%
# Histogramm
plt.hist(data['Wert'])
plt.show()

# Boxplot
sns.boxplot(data['Wert'])
plt.show()

# Scatterplot
#plt.scatter(data['Wert'], data['Datum'])
#plt.show()

# Korrelationsmatrix
csv_file_path = 'merged_tables.csv'
df = pd.read_csv(csv_file_path)

# Nur numerische Spalten auswählen 
numeric_columns = df.select_dtypes(include='number')

# Erstellen der Korrelationsmatrix
correlation_matrix = numeric_columns.corr()
print(correlation_matrix)
# Out:
#                    tempmax   tempmin      temp  feelslikemax  feelslikemin
# tempmax           1.000000  0.915963  0.981893      0.995377      0.922452  \
# tempmin           0.915963  1.000000  0.970482      0.915047      0.988363
# temp              0.981893  0.970482  1.000000      0.978604      0.968938
# feelslikemax      0.995377  0.915047  0.978604      1.000000      0.927305
# feelslikemin      0.922452  0.988363  0.968938      0.927305      1.000000
# feelslike         0.978607  0.964461  0.994487      0.982964      0.974965
# dew               0.873184  0.961962  0.928995      0.877924      0.960234
# humidity         -0.521186 -0.283757 -0.437091     -0.499827     -0.280244
# precip           -0.015664  0.116208  0.042263     -0.016649      0.092138
# precipprob       -0.083968  0.102197 -0.004940     -0.088534      0.070738
# precipcover      -0.133229  0.028491 -0.063627     -0.137618     -0.002937
# snow             -0.233863 -0.225855 -0.234893     -0.243518     -0.237140
# snowdepth        -0.355612 -0.377501 -0.369249     -0.363019     -0.381982
# windgust         -0.000573  0.041283  0.022982     -0.035750     -0.028426
# windspeed        -0.061322 -0.025453 -0.041016     -0.100307     -0.104120
# winddir           0.070670  0.135688  0.100911      0.065368      0.136197
# sealevelpressure -0.111658 -0.171222 -0.142969     -0.102477     -0.140548
# cloudcover       -0.417554 -0.155326 -0.305159     -0.412367     -0.190402
# visibility        0.344637  0.279284  0.327472      0.333340      0.270249
# solarradiation    0.730347  0.574675  0.679204      0.725703      0.585629
# solarenergy       0.730112  0.574405  0.678922      0.725446      0.585400
# uvindex           0.720293  0.550991  0.658758      0.716583      0.565606
# severerisk        0.366152  0.339348  0.360554      0.356786      0.332864
# moonphase         0.020841  0.023081  0.022109      0.021240      0.021978
# Wert             -0.160981 -0.270145 -0.219329     -0.144658     -0.230425
#
#                   feelslike       dew  humidity    precip  precipprob  ...
# tempmax            0.978607  0.873184 -0.521186 -0.015664   -0.083968  ...  \
# tempmin            0.964461  0.961962 -0.283757  0.116208    0.102197  ...
# temp               0.994487  0.928995 -0.437091  0.042263   -0.004940  ...
# feelslikemax       0.982964  0.877924 -0.499827 -0.016649   -0.088534  ...
# feelslikemin       0.974965  0.960234 -0.280244  0.092138    0.070738  ...
# feelslike          1.000000  0.930795 -0.414909  0.032926   -0.020778  ...
# dew                0.930795  1.000000 -0.077353  0.183261    0.149071  ...
# humidity          -0.414909 -0.077353  1.000000  0.339692    0.358135  ...
# precip             0.032926  0.183261  0.339692  1.000000    0.400877  ...
# precipprob        -0.020778  0.149071  0.358135  0.400877    1.000000  ...
# precipcover       -0.079196  0.084546  0.380267  0.531871    0.557908  ...
# snow              -0.245384 -0.212350  0.130750  0.112501    0.114202  ...
# snowdepth         -0.377242 -0.364920  0.117422  0.007664    0.058268  ...
# windgust          -0.034912 -0.008013 -0.119625  0.259110    0.343204  ...
# windspeed         -0.104074 -0.078669 -0.119295  0.210766    0.288086  ...
# winddir            0.096324  0.134121  0.042726  0.201639    0.310427  ...
# sealevelpressure  -0.122927 -0.173662 -0.030380 -0.235588   -0.304885  ...
# cloudcover        -0.314004 -0.114824  0.522760  0.323134    0.473902  ...
# visibility         0.312477  0.194842 -0.433884 -0.060326   -0.015969  ...
# solarradiation     0.678447  0.486182 -0.619802 -0.186404   -0.260577  ...
# solarenergy        0.678176  0.485885 -0.619747 -0.186757   -0.260773  ...
# uvindex            0.660378  0.461248 -0.632365 -0.211829   -0.267347  ...
# severerisk         0.352198  0.315741 -0.149515  0.049477    0.065823  ...
# moonphase          0.022097  0.018891 -0.012818 -0.025196   -0.007474  ...
# Wert              -0.189401 -0.254870 -0.010974 -0.287357   -0.412662  ...
#
#                    winddir  sealevelpressure  cloudcover  visibility
# tempmax           0.070670         -0.111658   -0.417554    0.344637  \
# tempmin           0.135688         -0.171222   -0.155326    0.279284
# temp              0.100911         -0.142969   -0.305159    0.327472
# feelslikemax      0.065368         -0.102477   -0.412367    0.333340
# feelslikemin      0.136197         -0.140548   -0.190402    0.270249
# feelslike         0.096324         -0.122927   -0.314004    0.312477
# dew               0.134121         -0.173662   -0.114824    0.194842
# humidity          0.042726         -0.030380    0.522760   -0.433884
# precip            0.201639         -0.235588    0.323134   -0.060326
# precipprob        0.310427         -0.304885    0.473902   -0.015969
# precipcover       0.254927         -0.243568    0.396441   -0.069432
# snow              0.033168         -0.106577    0.129503   -0.108886
# snowdepth        -0.004587         -0.043412    0.121809   -0.125018
# windgust          0.265650         -0.291710    0.238670    0.186661
# windspeed         0.235372         -0.271525    0.232437    0.138886
# winddir           1.000000         -0.176529    0.217074    0.106115
# sealevelpressure -0.176529          1.000000   -0.266022   -0.087187
# cloudcover        0.217074         -0.266022    1.000000   -0.170607
# visibility        0.106115         -0.087187   -0.170607    1.000000
# solarradiation   -0.108505         -0.015553   -0.498923    0.366279
# solarenergy      -0.108553         -0.015185   -0.499010    0.366345
# uvindex          -0.108871          0.008880   -0.528943    0.320108
# severerisk        0.098993         -0.115804   -0.185532    0.105538
# moonphase        -0.000384          0.009624   -0.004987   -0.000938
# Wert             -0.215973          0.224249   -0.203846   -0.308297
#
#                   solarradiation  solarenergy   uvindex  severerisk
# tempmax                 0.730347     0.730112  0.720293    0.366152  \
# tempmin                 0.574675     0.574405  0.550991    0.339348
# temp                    0.679204     0.678922  0.658758    0.360554
# feelslikemax            0.725703     0.725446  0.716583    0.356786
# feelslikemin            0.585629     0.585400  0.565606    0.332864
# feelslike               0.678447     0.678176  0.660378    0.352198
# dew                     0.486182     0.485885  0.461248    0.315741
# humidity               -0.619802    -0.619747 -0.632365   -0.149515
# precip                 -0.186404    -0.186757 -0.211829    0.049477
# precipprob             -0.260577    -0.260773 -0.267347    0.065823
# precipcover            -0.338897    -0.339393 -0.364179   -0.037120
# snow                   -0.168579    -0.168827 -0.188121   -0.042241
# snowdepth              -0.175904    -0.175862 -0.183742   -0.055150
# windgust               -0.118337    -0.118478 -0.117577    0.027017
# windspeed              -0.152634    -0.152707 -0.149118   -0.007849
# winddir                -0.108505    -0.108553 -0.108871    0.098993
# sealevelpressure       -0.015553    -0.015185  0.008880   -0.115804
# cloudcover             -0.498923    -0.499010 -0.528943   -0.185532
# visibility              0.366279     0.366345  0.320108    0.105538
# solarradiation          1.000000     0.999905  0.934771    0.322564
# solarenergy             0.999905     1.000000  0.934640    0.322125
# uvindex                 0.934771     0.934640  1.000000    0.292338
# severerisk              0.322564     0.322125  0.292338    1.000000
# moonphase               0.010703     0.010974  0.008517    0.013714
# Wert                    0.030384     0.030847  0.038556    0.074292
#
#                   moonphase      Wert
# tempmax            0.020841 -0.160981
# tempmin            0.023081 -0.270145
# temp               0.022109 -0.219329
# feelslikemax       0.021240 -0.144658
# feelslikemin       0.021978 -0.230425
# feelslike          0.022097 -0.189401
# dew                0.018891 -0.254870
# humidity          -0.012818 -0.010974
# precip            -0.025196 -0.287357
# precipprob        -0.007474 -0.412662
# precipcover       -0.023110 -0.412581
# snow              -0.020051 -0.026695
# snowdepth         -0.018719  0.092697
# windgust           0.002476 -0.351313
# windspeed          0.005442 -0.318042
# winddir           -0.000384 -0.215973
# sealevelpressure   0.009624  0.224249
# cloudcover        -0.004987 -0.203846
# visibility        -0.000938 -0.308297
# solarradiation     0.010703  0.030384
# solarenergy        0.010974  0.030847
# uvindex            0.008517  0.038556
# severerisk         0.013714  0.074292
# moonphase          1.000000  0.011634
# Wert               0.011634  1.000000
#
# [25 rows x 25 columns]
