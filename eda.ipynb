# %% [markdown]
# 1. Laden von Daten und Bibliotheken

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Daten laden
data = pd.read_csv('merged_tables.csv')

# %% [markdown]
# 2. Überblick über die Daten

# %%
# Ersten fünf Zeilen der Daten anzeigen
print(data.head())

# Datenform und Datentypen anzeigen
print(data.info())

# Statistische Zusammenfassung anzeigen
print(data.describe())
# Out:
#                       name  datetime  tempmax  tempmin  temp  feelslikemax
# 0  Zch_Stampfenbachstrasse  04.01.01      6.6      0.1   3.3           4.0  \
# 1  Zch_Stampfenbachstrasse  05.01.01      7.3      1.1   4.3           6.4
# 2  Zch_Stampfenbachstrasse  06.01.01      8.2      3.4   6.2           7.9
# 3  Zch_Stampfenbachstrasse  07.01.01      2.4      1.1   1.7           2.1
# 4  Zch_Stampfenbachstrasse  08.01.01      2.2      1.2   1.8           2.2
#
#    feelslikemin  feelslike  dew  humidity  ...
# 0           0.1        2.1  0.5      82.0  ...  \
# 1           1.1        3.9  1.9      84.8  ...
# 2           2.0        4.9  4.9      91.9  ...
# 3          -0.2        1.5  0.8      93.5  ...
# 4           1.2        1.8  0.8      92.9  ...
#
#                                          description  icon
# 0  Partly cloudy throughout the day with late aft...  rain  \
# 1        Partly cloudy throughout the day with rain.  rain
# 2  Cloudy skies throughout the day with a chance ...  rain
# 3  Cloudy skies throughout the day with a chance ...  rain
# 4  Cloudy skies throughout the day with a chance ...  rain
#
#                               stations     Datum                 Standort
# 0  06689099999,06670099999,06660099999  04.01.01  Zch_Stampfenbachstrasse  \
# 1  06689099999,06670099999,06660099999  05.01.01  Zch_Stampfenbachstrasse
# 2  06689099999,06670099999,06660099999  06.01.01  Zch_Stampfenbachstrasse
# 3  06689099999,06670099999,06660099999  07.01.01  Zch_Stampfenbachstrasse
# 4  06689099999,06670099999,06660099999  08.01.01  Zch_Stampfenbachstrasse
#
#    Parameter  Intervall  Einheit   Wert     Status
# 0       PM10         d1    µg/m3  22.84  bereinigt
# 1       PM10         d1    µg/m3  22.63  bereinigt
# 2       PM10         d1    µg/m3  10.93  bereinigt
# 3       PM10         d1    µg/m3    NaN  bereinigt
# 4       PM10         d1    µg/m3  18.01  bereinigt
#
# [5 rows x 40 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24450 entries, 0 to 24449
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              24450 non-null  object
#  1   datetime          24450 non-null  object
#  2   tempmax           24450 non-null  float64
#  3   tempmin           24450 non-null  float64
#  4   temp              24450 non-null  float64
#  5   feelslikemax      24450 non-null  float64
#  6   feelslikemin      24450 non-null  float64
#  7   feelslike         24450 non-null  float64
#  8   dew               24450 non-null  float64
#  9   humidity          24450 non-null  float64
#  10  precip            24450 non-null  float64
#  11  precipprob        24450 non-null  int64
#  12  precipcover       24450 non-null  float64
#  13  preciptype        13908 non-null  object
#  14  snow              24450 non-null  float64
#  15  snowdepth         24450 non-null  float64
#  16  windgust          18864 non-null  float64
#  17  windspeed         24450 non-null  float64
#  18  winddir           24450 non-null  float64
#  19  sealevelpressure  22260 non-null  float64
#  20  cloudcover        24450 non-null  float64
#  21  visibility        24360 non-null  float64
#  22  solarradiation    14607 non-null  float64
#  23  solarenergy       14607 non-null  float64
#  24  uvindex           14607 non-null  float64
#  25  severerisk        1431 non-null   float64
#  26  sunrise           24450 non-null  object
#  27  sunset            24450 non-null  object
#  28  moonphase         24450 non-null  float64
#  29  conditions        24450 non-null  object
#  30  description       24450 non-null  object
#  31  icon              24450 non-null  object
#  32  stations          24450 non-null  object
#  33  Datum             24450 non-null  object
#  34  Standort          24450 non-null  object
#  35  Parameter         24450 non-null  object
#  36  Intervall         24450 non-null  object
#  37  Einheit           24450 non-null  object
#  38  Wert              23607 non-null  float64
#  39  Status            24450 non-null  object
# dtypes: float64(24), int64(1), object(15)
# memory usage: 7.5+ MB
# None
#             tempmax       tempmin          temp  feelslikemax  feelslikemin
# count  24450.000000  24450.000000  24450.000000  24450.000000  24450.000000  \
# mean      14.085055      6.580454     10.049067     13.641276      5.426552
# std        8.837775      6.678150      7.503874      9.295292      7.739552
# min      -10.600000    -16.800000    -13.300000    -15.400000    -23.100000
# 25%        7.000000      1.200000      4.100000      5.800000     -0.700000
# 50%       14.300000      6.700000     10.200000     14.300000      5.600000
# 75%       21.000000     12.100000     16.000000     21.000000     12.100000
# max       36.200000     24.000000     27.500000     35.900000     24.000000
#
#           feelslike           dew      humidity        precip    precipprob
# count  24450.000000  24450.000000  24450.000000  24450.000000  24450.000000  \
# mean       9.322896      5.498785     76.011558      2.811476     56.576687
# std        8.242054      6.502936     12.028492      6.144332     49.566598
# min      -20.000000    -19.200000     36.000000      0.000000      0.000000
# 25%        2.500000      0.500000     67.800000      0.000000      0.000000
# 50%        9.800000      5.600000     77.600000      0.019500    100.000000
# 75%       16.000000     11.000000     85.500000      2.683000    100.000000
# max       28.600000     19.200000     99.300000     73.355000    100.000000
#
#        ...       winddir  sealevelpressure    cloudcover    visibility
# count  ...  24450.000000      22260.000000  24450.000000  24360.000000  \
# mean   ...    170.240699       1017.724771     64.413718     11.800813
# std    ...    105.728387          7.756560     25.452552      6.946393
# min    ...      0.000000        982.100000      0.000000      0.100000
# 25%    ...     47.500000       1013.200000     47.500000      8.300000
# 50%    ...    219.400000       1017.700000     70.800000     10.000000
# 75%    ...    250.200000       1022.500000     86.100000     12.800000
# max    ...    360.000000       1044.500000    100.000000     61.600000
#
#        solarradiation   solarenergy       uvindex   severerisk     moonphase
# count    14607.000000  14607.000000  14607.000000  1431.000000  24450.000000  \
# mean       145.397412     12.546313      5.294927    11.614256      0.482319
# std         93.068489      8.043677      2.589642     6.740498      0.288589
# min          2.200000      0.000000      0.000000    10.000000      0.000000
# 25%         68.200000      5.900000      3.000000    10.000000      0.250000
# 50%        128.600000     11.100000      5.000000    10.000000      0.480000
# 75%        216.700000     18.700000      8.000000    10.000000      0.750000
# max        377.200000     32.700000     10.000000    60.000000      0.980000
#
#                Wert
# count  23607.000000
# mean      21.127181
# std       13.262062
# min        0.930000
# 25%       12.060000
# 50%       17.950000
# 75%       26.550000
# max      163.450000
#
# [8 rows x 25 columns]

# %% [markdown]
# 3. Visualisierung von Daten

# %%
# Histogramm
plt.hist(data['Wert'])
plt.show()

# Boxplot
sns.boxplot(data['Wert'])
plt.show()

# Scatterplot
#plt.scatter(data['Wert'], data['Datum'])
#plt.show()

# Korrelationsmatrix
csv_file_path = 'merged_tables.csv'
df = pd.read_csv(csv_file_path)

# Nur numerische Spalten auswählen 
numeric_columns = df.select_dtypes(include='number')

# Erstellen der Korrelationsmatrix
correlation_matrix = numeric_columns.corr()
correlation_table = correlation_matrix.style.background_gradient(cmap='coolwarm')
correlation_table
# Out:
# <style type="text/css">
