# %% [markdown]
# # Jupyter with PostgreSQL

# %% [markdown]
# ## Libararies and Settings

# %%
# Variables
import config
import preprocessing_functions as pf

# Libraries
import pandas as pd




# Settings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Create database connection

# %%
#Connection using preprocessing function
pf.db_connect(config.db_name)

#Connection using explicit programming
#conn = psycopg2.connect("host=localhost dbname=postgres user=admin password=secret")

# %% [markdown]
# ## Read data

# %%
# CSV-Datei mit den Daten
#csv_file = 'ausgabe.csv'

df = pd.read_csv(config.csv_file, sep=',')
df.head(5)
# Out:
#    weathercode_best_match  temperature_2m_max_best_match  \
# 0                      80                           10.8
# 1                       3                           13.1
# 2                      45                           16.6
# 3                      80                           14.1
# 4                      61                           14.3
#
#    temperature_2m_min_best_match  apparent_temperature_max_best_match  \
# 0                            5.7                                  8.1
# 1                            5.1                                 10.3
# 2                            3.9                                 15.0
# 3                            9.5                                 11.8
# 4                            8.6                                 11.7
#
#    apparent_temperature_min_best_match           sunrise            sunset  \
# 0                                  4.1  2023-04-08T06:49  2023-04-08T20:05
# 1                                  2.8  2023-04-09T06:47  2023-04-09T20:07
# 2                                  1.6  2023-04-10T06:45  2023-04-10T20:08
# 3                                  6.7  2023-04-11T06:43  2023-04-11T20:10
# 4                                  5.9  2023-04-12T06:41  2023-04-12T20:11
#
#    uv_index_max_best_match  uv_index_clear_sky_max_best_match  \
# 0                     5.25                               5.35
# 1                     5.45                               5.45
# 2                     5.40                               5.70
# 3                     3.05                               5.40
# 4                     4.65                               5.90
#
#    precipitation_sum_best_match  ...  \
# 0                           0.3  ...
# 1                           0.0  ...
# 2                           0.0  ...
# 3                          11.5  ...
# 4                           8.2  ...
#
#    apparent_temperature_min_meteofrance_seamless  \
# 0                                            2.0
# 1                                            1.2
# 2                                            0.6
# 3                                            6.7
# 4                                            5.2
#
#    precipitation_sum_meteofrance_seamless  snowfall_sum_meteofrance_seamless  \
# 0                                     4.8                                0.0
# 1                                     0.0                                0.0
# 2                                     0.0                                0.0
# 3                                     4.1                                0.0
# 4                                     8.7                                0.0
#
#    precipitation_hours_meteofrance_seamless  \
# 0                                       4.0
# 1                                       0.0
# 2                                       0.0
# 3                                       7.0
# 4                                      14.0
#
#    windspeed_10m_max_meteofrance_seamless  \
# 0                                    10.7
# 1                                    12.0
# 2                                     7.7
# 3                                    18.5
# 4                                    20.5
#
#    windgusts_10m_max_meteofrance_seamless  \
# 0                                    29.5
# 1                                    29.5
# 2                                    30.6
# 3                                    42.5
# 4                                    46.1
#
#    winddirection_10m_dominant_meteofrance_seamless  \
# 0                                               82
# 1                                               44
# 2                                              264
# 3                                              247
# 4                                              224
#
#    shortwave_radiation_sum_meteofrance_seamless  \
# 0                                         18.95
# 1                                         24.23
# 2                                         23.03
# 3                                         10.63
# 4                                         11.09
#
#    et0_fao_evapotranspiration_meteofrance_seamless  AQI - BAFU
# 0                                             2.44           7
# 1                                             3.37          11
# 2                                             3.61           8
# 3                                             2.08           5
# 4                                             1.96           4
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Write data to database

# %%
#engine = create_engine('postgresql://admin:secret@localhost:5432/postgres')
df.to_sql(config.db_table, config.db_engine, if_exists='replace', index=False)
# Out:
# 30

# %% [markdown]
# ## Make SQL query

# %%
SQLquery = text('SELECT * FROM ' + config.db_table)

df_sub = pd.read_sql('SELECT * FROM ' + config.db_table, con=config.db_engine.connect())
df_sub.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\stump\anaconda3\envs\ADSenv\lib\site-packages\sqlalchemy\engine\base.py:1410, in Connection.execute(self, statement, parameters, execution_options)
#    1409 try:
# -> 1410     meth = statement._execute_on_connection
#    1411 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_sub = pd.read_sql('SELECT * FROM ' + config.db_table, con=config.db_engine.connect())
#       2 df_sub.head()
#
# File c:\Users\stump\anaconda3\envs\ADSenv\lib\site-packages\pandas\io\sql.py:590, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     581     return pandas_sql.read_table(
#     582         sql,
#     583         index_col=index_col,
#    (...)
#     587         chunksize=chunksize,
#     588     )
#     589 else:
# --> 590     return pandas_sql.read_query(
#     591         sql,
#     592         index_col=index_col,
#     593         params=params,
#     594         coerce_float=coerce_float,
#     595         parse_dates=parse_dates,
#     596         chunksize=chunksize,
#     597     )
#
# File c:\Users\stump\anaconda3\envs\ADSenv\lib\site-packages\pandas\io\sql.py:1560, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1512 """
#    1513 Read SQL query into a DataFrame.
#    1514
#    (...)
#    1556
#    1557 """
#    1558 args = _convert_params(sql, params)
# -> 1560 result = self.execute(*args)
#    1561 columns = result.keys()
#    1563 if chunksize is not None:
#
# File c:\Users\stump\anaconda3\envs\ADSenv\lib\site-packages\pandas\io\sql.py:1405, in SQLDatabase.execute(self, *args, **kwargs)
#    1403 def execute(self, *args, **kwargs):
#    1404     """Simple passthrough to SQLAlchemy connectable"""
# -> 1405     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File c:\Users\stump\anaconda3\envs\ADSenv\lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     meth = statement._execute_on_connection
#    1411 except AttributeError as err:
# -> 1412     raise exc.ObjectNotExecutableError(statement) from err
#    1413 else:
#    1414     return meth(
#    1415         self,
#    1416         distilled_parameters,
#    1417         execution_options or NO_OPTIONS,
#    1418     )
#
# ObjectNotExecutableError: Not an executable object: 'SELECT * FROM AQI_RAW'

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-05-09 18:50:14
# Python Version: 3.10.9
# -----------------------------------
